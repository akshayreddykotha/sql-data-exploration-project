# %% [markdown]
# ### Load SQL Magics

# %%
# %load_ext sql

# %% [markdown]
# ### Load sqlalchemy to create a local environment of PostgreSQL server

# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
# %sql dialect+driver://username:password@host:port/database
# %sql postgresql://jovyan:postgres@localhost:8765/rsm-docker
# Out:
# 'Connected: jovyan@rsm-docker'

# %% [markdown]
# ### Create engine

# %%
engine = create_engine("postgresql://jovyan:postgres@localhost:8765/rsm-docker")

# %%
engine
# Out:
# Engine(postgresql://jovyan:***@localhost:8765/rsm-docker)

# %% [markdown]
# ### Get files as data frames

# %%
accounts = pd.read_excel("data/accounts.xlsx")
orders = pd.read_excel("data/orders.xlsx")
region = pd.read_excel("data/region.xlsx")
sales_reps = pd.read_excel("data/sales_reps.xlsx")
web_events = pd.read_excel("data/web_events.xlsx")

# %% [markdown]
# ### Data ingestion to tables in a database (here - rsm-docker)

# %%
accounts.to_sql("accounts", engine, if_exists="replace")
orders.to_sql("orders", engine, if_exists="replace")
region.to_sql("region", engine, if_exists="replace")
sales_reps.to_sql("sales_reps", engine, if_exists="replace")
web_events.to_sql("web_events", engine, if_exists="replace")

# %%
engine.table_names()
# Out:
# ['web_events', 'orders', 'region', 'sales_reps', 'ACCOUNTS', 'accounts']

# %% [markdown]
# ## Queries

# %% [markdown]
# ### 1. Use DISTINCT to test if there are any accounts associated with more than one region.

# %%
# %%sql
#
# SELECT DISTINCT a.name, r.name as reg_name
# FROM accounts a
# JOIN sales_reps s
# ON s.id = a.sales_rep_id
# JOIN region r
# ON r.id = s.region_id;
# Out:
#  * postgresql://jovyan:***@localhost:8765/rsm-docker
# 351 rows affected.
# [('Sempra Energy', 'West'),
#  ('Texas Instruments', 'Southeast'),
#  ('Southern', 'Southeast'),
#  ('Voya Financial', 'West'),
#  ('Gap', 'Southeast'),
#  ('FirstEnergy', 'Southeast'),
#  ('Johnson Controls', 'Northeast'),
#  ('Group 1 Automotive', 'West'),
#  ('Oracle', 'Northeast'),
#  ('Northrop Grumman', 'Midwest'),
#  ('Stryker', 'West'),
#  ('Reliance Steel & Aluminum', 'West'),
#  ('FedEx', 'Northeast'),
#  ('Consolidated Edison', 'Southeast'),
#  ('Bank of New York Mellon Corp.', 'Southeast'),
#  ("Kohl's", 'Midwest'),
#  ('J.P. Morgan Chase', 'Northeast'),
#  ('Campbell Soup', 'West'),
#  ('Nationwide', 'Northeast'),
#  ('Eastman Chemical', 'West'),
#  ('J.C. Penney', 'Southeast'),
#  ('Las Vegas Sands', 'Southeast'),
#  ('Delta Air Lines', 'Northeast'),
#  ('Whole Foods Market', 'Southeast'),
#  ('Eversource Energy', 'West'),
#  ('Marsh & McLennan', 'Southeast'),
#  ('Staples', 'Midwest'),
#  ('Alcoa', 'Midwest'),
#  ('Amazon.com', 'Northeast'),
#  ('United Technologies', 'Northeast'),
#  ('BlackRock', 'Southeast'),
#  ('Prudential Financial', 'Northeast'),
#  ('KKR', 'West'),
#  ('Gilead Sciences', 'Northeast'),
#  ('State Street Corp.', 'West'),
#  ('DaVita HealthCare Partners', 'Southeast'),
#  ('Duke Energy', 'Midwest'),
#  ('Target', 'Northeast'),
#  ('Reinsurance Group of America', 'West'),
#  ('Waste Management', 'Southeast'),
#  ('Discover Financial Services', 'West'),
#  ('AbbVie', 'Midwest'),
#  ('Entergy', 'Southeast'),
#  ('HCA Holdings', 'Northeast'),
#  ('Chesapeake Energy', 'Southeast'),
#  ('Bank of America Corp.', 'Northeast'),
#  ('NGL Energy Partners', 'Southeast'),
#  ('Marriott International', 'Southeast'),
#  ('USAA', 'Midwest'),
#  ('ManpowerGroup', 'Midwest'),
#  ('Kimberly-Clark', 'Midwest'),
#  ('Principal Financial', 'Southeast'),
#  ('Cardinal Health', 'Northeast'),
#  ('Marathon Petroleum', 'Northeast'),
#  ('Aramark', 'Southeast'),
#  ('CBRE Group', 'West'),
#  ('General Mills', 'Southeast'),
#  ('Stanley Black & Decker', 'West'),
#  ('D.R. Horton', 'West'),
#  ('HP', 'Northeast'),
#  ('Hormel Foods', 'West'),
#  ('Lincoln National', 'Southeast'),
#  ('Universal Health Services', 'West'),
#  ('Ameriprise Financial', 'Southeast'),
#  ('Hilton Worldwide Holdings', 'West'),
#  ('C.H. Robinson Worldwide', 'Southeast'),
#  ('Mondelez International', 'Northeast'),
#  ('AECOM', 'Southeast'),
#  ('Performance Food Group', 'Southeast'),
#  ('PayPal Holdings', 'West'),
#  ('Kellogg', 'Southeast'),
#  ('Express Scripts Holding', 'Northeast'),
#  ('MetLife', 'Northeast'),
#  ('Cigna', 'Northeast'),
#  ('EOG Resources', 'West'),
#  ('Unum Group', 'West'),
#  ('Northwestern Mutual', 'Northeast'),
#  ('Goodyear Tire & Rubber', 'Southeast'),
#  ('Visa', 'Southeast'),
#  ('American Electric Power', 'Southeast'),
#  ('Best Buy', 'Northeast'),
#  ('Becton Dickinson', 'West'),
#  ('Applied Materials', 'West'),
#  ('AmerisourceBergen', 'Northeast'),
#  ('Office Depot', 'Southeast'),
#  ('Johnson & Johnson', 'Northeast'),
#  ('U.S. Bancorp', 'Midwest'),
#  ('Union Pacific', 'Midwest'),
#  ('Bed Bath & Beyond', 'Southeast'),
#  ('National Oilwell Varco', 'Southeast'),
#  ('AES', 'Southeast'),
#  ('Viacom', 'Southeast'),
#  ('Alphabet', 'Northeast'),
#  ('Genworth Financial', 'West'),
#  ('Public Service Enterprise Group', 'West'),
#  ('Global Partners', 'West'),
#  ('Newmont Mining', 'West'),
#  ("Lowe's", 'Northeast'),
#  ('United States Steel', 'Southeast'),
#  ('Nordstrom', 'Southeast'),
#  ('Icahn Enterprises', 'Southeast'),
#  ('Veritiv', 'West'),
#  ('Yum Brands', 'Southeast'),
#  ('World Fuel Services', 'Northeast'),
#  ('US Foods Holding', 'Midwest'),
#  ('HollyFrontier', 'Southeast'),
#  ('Synnex', 'Southeast'),
#  ('Philip Morris International', 'Northeast'),
#  ('PVH', 'West'),
#  ('Leucadia National', 'Southeast'),
#  ('Lennar', 'West'),
#  ('Abbott Laboratories', 'Midwest'),
#  ('INTL FCStone', 'Northeast'),
#  ('Paccar', 'Midwest'),
#  ('Aetna', 'Northeast'),
#  ('Precision Castparts', 'West'),
#  ('Chevron', 'Northeast'),
#  ('Microsoft', 'Northeast'),
#  ('CenturyLink', 'Southeast'),
#  ('Tesoro', 'Northeast'),
#  ('State Farm Insurance Cos.', 'Northeast'),
#  ("Macy's", 'Northeast'),
#  ('Computer Sciences', 'Southeast'),
#  ('Sears Holdings', 'Midwest'),
#  ('Sherwin-Williams', 'West'),
#  ('NextEra Energy', 'Southeast'),
#  ('Guardian Life Ins. Co. of America', 'Southeast'),
#  ('McKesson', 'Northeast'),
#  ('Raytheon', 'Midwest'),
#  ('3M', 'Northeast'),
#  ('Starbucks', 'Midwest'),
#  ('Franklin Resources', 'West'),
#  ('Emerson Electric', 'Midwest'),
#  ('BB&T Corp.', 'West'),
#  ('Honeywell International', 'Northeast'),
#  ('DISH Network', 'Southeast'),
#  ('United Continental Holdings', 'Northeast'),
#  ('Nucor', 'Southeast'),
#  ('Liberty Mutual Insurance Group', 'Northeast'),
#  ('WestRock', 'West'),
#  ('AutoZone', 'West'),
#  ('Broadcom', 'West'),
#  ('Huntsman', 'West'),
#  ('Air Products & Chemicals', 'West'),
#  ('CDW', 'Southeast'),
#  ('Rite Aid', 'Midwest'),
#  ('Ross Stores', 'Southeast'),
#  ('Publix Super Markets', 'Northeast'),
#  ('Tenet Healthcare', 'Midwest'),
#  ('Fannie Mae', 'Northeast'),
#  ('Dow Chemical', 'Northeast'),
#  ('Southwest Airlines', 'Midwest'),
#  ('Exelon', 'Northeast'),
#  ('Dean Foods', 'West'),
#  ('Community Health Systems', 'Midwest'),
#  ('Parker-Hannifin', 'Southeast'),
#  ('Anthem', 'Northeast'),
#  ('Time Warner Cable', 'Midwest'),
#  ('Illinois Tool Works', 'Southeast'),
#  ('Health Net', 'Southeast'),
#  ('Time Warner', 'Northeast'),
#  ('Danaher', 'Midwest'),
#  ('Edison International', 'Southeast'),
#  ('NRG Energy', 'Southeast'),
#  ('DTE Energy', 'West'),
#  ('Citigroup', 'Northeast'),
#  ('Disney', 'Northeast'),
#  ('Genuine Parts', 'Southeast'),
#  ('Pfizer', 'Northeast'),
#  ('Nike', 'Northeast'),
#  ('Enterprise Products Partners', 'Northeast'),
#  ('VF', 'Southeast'),
#  ('Mohawk Industries', 'West'),
#  ('SunTrust Banks', 'West'),
#  ('Celgene', 'West'),
#  ('General Electric', 'Northeast'),
#  ('AT&T', 'Northeast'),
#  ('Walgreens Boots Alliance', 'Northeast'),
#  ('Liberty Interactive', 'West'),
#  ('CST Brands', 'West'),
#  ('Arrow Electronics', 'Midwest'),
#  ('Univar', 'West'),
#  ('CHS', 'Northeast'),
#  ('Hertz Global Holdings', 'West'),
#  ('Avnet', 'Northeast'),
#  ('Owens & Minor', 'West'),
#  ('Xerox', 'Midwest'),
#  ('Ally Financial', 'West'),
#  ('UPS', 'Northeast'),
#  ('Omnicom Group', 'Southeast'),
#  ('PepsiCo', 'Northeast'),
#  ('Twenty-First Century Fox', 'Northeast'),
#  ('PPL', 'West'),
#  ('Cisco Systems', 'Northeast'),
#  ("McDonald's", 'Midwest'),
#  ('International Paper', 'Midwest'),
#  ('Anadarko Petroleum', 'West'),
#  ('MGM Resorts International', 'West'),
#  ('Xcel Energy', 'West'),
#  ('SpartanNash', 'West'),
#  ("Peter Kiewit Sons'", 'West'),
#  ('DuPont', 'Northeast'),
#  ('W.W. Grainger', 'West'),
#  ('Kroger', 'Northeast'),
#  ('Walmart', 'Northeast'),
#  ('Sonic Automotive', 'West'),
#  ('Capital One Financial', 'Midwest'),
#  ('Avis Budget Group', 'West'),
#  ('Dollar General', 'Midwest'),
#  ('Kinder Morgan', 'Southeast'),
#  ('Henry Schein', 'West'),
#  ('WellCare Health Plans', 'Southeast'),
#  ('American Express', 'Northeast'),
#  ('Monsanto', 'Southeast'),
#  ('Lithia Motors', 'West'),
#  ('Aflac', 'Midwest'),
#  ('UnitedHealth Group', 'Northeast'),
#  ('Masco', 'West'),
#  ('Republic Services', 'West'),
#  ('Qualcomm', 'Midwest'),
#  ('Crown Holdings', 'West'),
#  ('Coca-Cola', 'Northeast'),
#  ('Navistar International', 'West'),
#  ('Kraft Heinz', 'Midwest'),
#  ('Freddie Mac', 'Northeast'),
#  ("O'Reilly Automotive", 'West'),
#  ('Boeing', 'Northeast'),
#  ('Ecolab', 'Southeast'),
#  ('Cognizant Technology Solutions', 'Southeast'),
#  ('Oneok', 'West'),
#  ('CarMax', 'Southeast'),
#  ('Baker Hughes', 'Southeast'),
#  ('Apple', 'Northeast'),
#  ('Cummins', 'Midwest'),
#  ('Priceline Group', 'West'),
#  ('Intel', 'Northeast'),
#  ('Archer Daniels Midland', 'Northeast'),
#  ('Devon Energy', 'Southeast'),
#  ('CSX', 'Southeast'),
#  ('Jarden', 'West'),
#  ('IBM', 'Northeast'),
#  ('Pacific Life', 'West'),
#  ('Amgen', 'Midwest'),
#  ('Norfolk Southern', 'West'),
#  ('ADP', 'Southeast'),
#  ('Caterpillar', 'Northeast'),
#  ('Farmers Insurance Exchange', 'Southeast'),
#  ('Progressive', 'Midwest'),
#  ('Lear', 'Midwest'),
#  ('ConocoPhillips', 'Northeast'),
#  ('Verizon', 'Northeast'),
#  ('News Corp.', 'West'),
#  ('Costco', 'Northeast'),
#  ('Ball', 'West'),
#  ('TIAA', 'Northeast'),
#  ('PPG Industries', 'Southeast'),
#  ('Charter Communications', 'West'),
#  ('Reynolds American', 'West'),
#  ('First Data', 'Southeast'),
#  ('Level 3 Communications', 'West'),
#  ('Advance Auto Parts', 'West'),
#  ('Freeport-McMoRan', 'Southeast'),
#  ('Occidental Petroleum', 'Southeast'),
#  ('Morgan Stanley', 'Northeast'),
#  ('General Motors', 'Northeast'),
#  ('Western Digital', 'Southeast'),
#  ('Dollar Tree', 'Southeast'),
#  ('General Dynamics', 'Northeast'),
#  ("Toys 'R' Us", 'Southeast'),
#  ('Tenneco', 'West'),
#  ('Penske Automotive Group', 'Midwest'),
#  ('Baxter International', 'West'),
#  ('Allstate', 'Northeast'),
#  ('R.R. Donnelley & Sons', 'West'),
#  ('PBF Energy', 'Southeast'),
#  ('Centene', 'Midwest'),
#  ('Laboratory Corp. of America', 'West'),
#  ('PNC Financial Services Group', 'Southeast'),
#  ('Home Depot', 'Northeast'),
#  ('Praxair', 'West'),
#  ('Valero Energy', 'Northeast'),
#  ('American Airlines Group', 'Northeast'),
#  ('Corning', 'West'),
#  ('Phillips 66', 'Northeast'),
#  ('Assurant', 'West'),
#  ('Exxon Mobil', 'Northeast'),
#  ('Ingram Micro', 'Northeast'),
#  ('Estee Lauder', 'West'),
#  ('Deere', 'Northeast'),
#  ('Biogen', 'West'),
#  ('Tech Data', 'Midwest'),
#  ('Jacobs Engineering Group', 'Southeast'),
#  ('AutoNation', 'Midwest'),
#  ('Whirlpool', 'Midwest'),
#  ('AIG', 'Northeast'),
#  ('Halliburton', 'Midwest'),
#  ('L-3 Communications', 'Southeast'),
#  ('Altria Group', 'Midwest'),
#  ('Thermo Fisher Scientific', 'Southeast'),
#  ('Cameron International', 'West'),
#  ('Bristol-Myers Squibb', 'Southeast'),
#  ('Tyson Foods', 'Northeast'),
#  ('Hartford Financial Services Group', 'Midwest'),
#  ('Thrivent Financial for Lutherans', 'West'),
#  ('Molina Healthcare', 'Southeast'),
#  ('Facebook', 'Southeast'),
#  ('MasterCard', 'West'),
#  ('Sysco', 'Northeast'),
#  ('PG&E Corp.', 'Southeast'),
#  ('Lockheed Martin', 'Northeast'),
#  ('United Natural Foods', 'West'),
#  ('Ford Motor', 'Northeast'),
#  ('eBay', 'West'),
#  ('Travelers Cos.', 'Northeast'),
#  ('Procter & Gamble', 'Northeast'),
#  ('Humana', 'Northeast'),
#  ('Berkshire Hathaway', 'Northeast'),
#  ('Comcast', 'Northeast'),
#  ('Jabil Circuit', 'Southeast'),
#  ('Wells Fargo', 'Northeast'),
#  ('Western Refining', 'West'),
#  ('American Family Insurance Group', 'West'),
#  ('Merck', 'Northeast'),
#  ('Fluor', 'Southeast'),
#  ('Massachusetts Mutual Life Insurance', 'Northeast'),
#  ('Eli Lilly', 'Midwest'),
#  ('Core-Mark Holding', 'West'),
#  ('Fidelity National Financial', 'West'),
#  ('Textron', 'Southeast'),
#  ('Energy Transfer Equity', 'Northeast'),
#  ('Colgate-Palmolive', 'Southeast'),
#  ('Dominion Resources', 'Southeast'),
#  ('L Brands', 'Southeast'),
#  ("Land O'Lakes", 'Southeast'),
#  ('GameStop', 'West'),
#  ('BorgWarner', 'West'),
#  ('TJX', 'Northeast'),
#  ('HD Supply Holdings', 'West'),
#  ('Murphy USA', 'West'),
#  ('CVS Health', 'Northeast'),
#  ('EMC', 'Midwest'),
#  ('CBS', 'Southeast'),
#  ('Loews', 'Southeast'),
#  ('Mosaic', 'West'),
#  ('Plains GP Holdings', 'Midwest'),
#  ('ConAgra Foods', 'Southeast'),
#  ('New York Life Insurance', 'Northeast'),
#  ('Supervalu', 'Southeast'),
#  ('Micron Technology', 'Southeast'),
#  ('Goldman Sachs Group', 'Northeast'),
#  ('Autoliv', 'West')]

# %%
# %%sql
#
# SELECT COUNT(*)
# FROM accounts a
# JOIN sales_reps s
# ON s.id = a.sales_rep_id
# JOIN region r
# ON r.id = s.region_id;
# Out:
#  * postgresql://jovyan:***@localhost:8765/rsm-docker
# 1 rows affected.
# [(351,)]

# %% [markdown]
# * Even without distinct the number of row entries is same which implies there are no accounts associated with more than one region.

# %% [markdown]
# ### 2. Have any sales reps worked on more than one account?

# %%
# %%sql
#
# SELECT s.name, COUNT(*) no_accounts
# FROM accounts a
# JOIN sales_reps s
# ON s.id = a.sales_rep_id
# GROUP BY s.name
# ORDER BY no_accounts;
# Out:
#  * postgresql://jovyan:***@localhost:8765/rsm-docker
# 50 rows affected.
# [('Ernestine Pickron', 3),
#  ('Cordell Rieder', 3),
#  ('Nakesha Renn', 3),
#  ('Silvana Virden', 3),
#  ('Retha Sears', 3),
#  ('Ayesha Monica', 3),
#  ('Akilah Drinkard', 3),
#  ('Shawanda Selke', 3),
#  ('Kathleen Lalonde', 4),
#  ('Julie Starr', 4),
#  ('Lavera Oles', 4),
#  ('Renetta Carew', 4),
#  ('Cara Clarke', 4),
#  ('Carletta Kosinski', 5),
#  ('Sherlene Wetherington', 5),
#  ('Chau Rowles', 5),
#  ('Samuel Racine', 6),
#  ('Elba Felder', 6),
#  ('Necole Victory', 6),
#  ('Sibyl Lauria', 6),
#  ('Eugena Esser', 6),
#  ('Debroah Wardle', 6),
#  ('Charles Bidwell', 7),
#  ('Cliff Meints', 7),
#  ('Gianna Dossey', 7),
#  ('Michel Averette', 7),
#  ('Babette Soukup', 7),
#  ('Soraya Fulton', 7),
#  ('Nelle Meaux', 7),
#  ('Derrick Boggess', 7),
#  ('Elna Condello', 7),
#  ('Delilah Krum', 8),
#  ('Julia Behrman', 8),
#  ('Tia Amato', 8),
#  ('Dawna Agnew', 9),
#  ('Marquetta Laycock', 9),
#  ('Elwood Shutt', 9),
#  ('Saran Ram', 10),
#  ('Moon Torian', 10),
#  ('Arica Stoltzfus', 10),
#  ('Hilma Busick', 10),
#  ('Brandie Riva', 10),
#  ('Vernita Plump', 11),
#  ('Earlie Schleusner', 11),
#  ('Maren Musto', 11),
#  ('Dorotha Seawell', 11),
#  ('Micha Woodford', 11),
#  ('Maryanna Fiorentino', 11),
#  ('Calvin Ollison', 11),
#  ('Georgianna Chisholm', 15)]

# %%
# %%sql
#
# SELECT DISTINCT s.id, s.name
# FROM sales_reps s;
# Out:
#  * postgresql://jovyan:***@localhost:8765/rsm-docker
# 50 rows affected.
# [(321870, 'Derrick Boggess'),
#  (321500, 'Samuel Racine'),
#  (321580, 'Sibyl Lauria'),
#  (321550, 'Lavera Oles'),
#  (321860, 'Saran Ram'),
#  (321820, 'Dorotha Seawell'),
#  (321700, 'Debroah Wardle'),
#  (321740, 'Charles Bidwell'),
#  (321780, 'Julie Starr'),
#  (321600, 'Ernestine Pickron'),
#  (321510, 'Eugena Esser'),
#  (321750, 'Cliff Meints'),
#  (321760, 'Delilah Krum'),
#  (321690, 'Gianna Dossey'),
#  (321810, 'Moon Torian'),
#  (321950, 'Elwood Shutt'),
#  (321630, 'Julia Behrman'),
#  (321960, 'Maryanna Fiorentino'),
#  (321540, 'Cara Clarke'),
#  (321900, 'Soraya Fulton'),
#  (321560, 'Elba Felder'),
#  (321880, 'Babette Soukup'),
#  (321770, 'Kathleen Lalonde'),
#  (321930, 'Hilma Busick'),
#  (321840, 'Vernita Plump'),
#  (321850, 'Calvin Ollison'),
#  (321800, 'Earlie Schleusner'),
#  (321640, 'Tia Amato'),
#  (321670, 'Nakesha Renn'),
#  (321720, 'Chau Rowles'),
#  (321620, 'Retha Sears'),
#  (321890, 'Nelle Meaux'),
#  (321790, 'Cordell Rieder'),
#  (321680, 'Elna Condello'),
#  (321650, 'Akilah Drinkard'),
#  (321660, 'Silvana Virden'),
#  (321970, 'Georgianna Chisholm'),
#  (321920, 'Marquetta Laycock'),
#  (321830, 'Maren Musto'),
#  (321610, 'Ayesha Monica'),
#  (321990, 'Dawna Agnew'),
#  (321730, 'Carletta Kosinski'),
#  (321910, 'Brandie Riva'),
#  (321570, 'Shawanda Selke'),
#  (321940, 'Arica Stoltzfus'),
#  (321590, 'Necole Victory'),
#  (321710, 'Sherlene Wetherington'),
#  (321530, 'Renetta Carew'),
#  (321520, 'Michel Averette'),
#  (321980, 'Micha Woodford')]

# %% [markdown]
# * All of the sales reps worked on more than 1 account.
